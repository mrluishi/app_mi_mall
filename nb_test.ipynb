# %%
import sqlalchemy
import pyodbc
import pandas as pd

# %%
engine = sqlalchemy.create_engine('mssql+pyodbc://' + 'testLogin1' + ':' + 'Prueba1&' + '@'
        + 'srvsqlmallaventura.database.windows.net' + ':1433/' + 'dbsqlmallaventura' + '?DRIVER=' + 'ODBC Driver 17 for SQL Server')

df = pd.read_sql_table('MI_H_Reporte_1', engine, schema='prod')
# Out:
# C:\Users\luigi.flores\AppData\Local\Temp\ipykernel_21344\2721863791.py:1: SAWarning: No driver name specified; this is expected by PyODBC when using DSN-less connections
#   engine = sqlalchemy.create_engine('mssql+pyodbc://' + 'testLogin1' + ':' + 'Prueba1&' + '@'

# %%
df.head()
# Out:
#   CODMALL             NOMBREMALL NOMBRESUBGERENTE CODCENTROBENEFICIO  \
# 0   PEM07  Mall Aventura Iquitos              N/A         PEM0074001
# 1   PEM07  Mall Aventura Iquitos              N/A         PEM0071001
# 2   PEM07  Mall Aventura Iquitos              N/A         PEM0071001
# 3   PEM07  Mall Aventura Iquitos              N/A         PEM0071001
# 4   PEM07  Mall Aventura Iquitos              N/A         PEM0071001
#
#   NOMBRECENTROBENEFICIO CODRAMO            NOMBRERAMO    GRUPORAMO  \
# 0  Kioskos y Módulos AQ   SR514  Computación y Acceso  Informática
# 1             TM Retail   SR911   Vestuario masculino   Vestuarios
# 2             TM Retail   SR661   Opticas y Lentes de      Opticas
# 3             TM Retail   SR515   Electrónica General  Informática
# 4             TM Retail   SR821             Farmacias        Salud
#
#        NOMBRELOCATARIO CODCONTRATO  ... TAMLIMITESALUDABLE  \
# 0  SOMOSTEL MODULO AIQ     3003084  ...                NaN
# ...
